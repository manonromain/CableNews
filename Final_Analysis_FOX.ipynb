# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import pickle
from tqdm import tqdm
import operator

sns.set()

# %matplotlib inline

# %% [markdown]
# ### Topic: Male vs. Female

# %%
def topic_male_vs_female(channel):
    topics = {}
    for topic in ['Other', 'Politics', 'Media', 'Fashion', 'Foreign Policy', 'Immigration', 
         'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Violence', 'Climate']:
        topics[topic] = {'count': 0, 'male': 0, 'female': 0, 'ratio': 0,
                         'male_number': [0, 0, 0, 0, 0], 'female_number': [0, 0, 0, 0, 0],
                        'male_total_ratio': [], 'conditional_male_total_ratio': []} #1, 2, 3, 4, 5
    
    all_files = glob.glob('processed_data/%s/*.p'%channel)
    
    for file in all_files:
        data = pickle.load(open(file, 'rb'))
        for key in data.keys():
            topic = data[key]['Topics'][0]
            topics[topic]['count'] += 1
            if data[key]['gender'] is not None:
                for elements in data[key]['gender']:
                    if elements == 'm':
                        topics[topic]['male'] += 1
                    else:
                        topics[topic]['female'] += 1

                all_genders = np.array(data[key]['gender'])
                num_men = all_genders[all_genders=='m'].shape[0]
                num_female = all_genders[all_genders=='f'].shape[0]
                topics[topic]['male_total_ratio'].append(num_men/(num_men + num_female))
                if num_men + num_female >= 3:
                    topics[topic]['conditional_male_total_ratio'].append(num_men/(num_men + num_female))
                if len(all_genders) == 1:
                        continue
                if num_men > 0:
                    num_men = min(num_men-1, 4)
                    topics[topic]['male_number'][num_men] += 1
                if num_female > 0:
                    num_female = min(num_female-1, 4)
                    topics[topic]['female_number'][num_female] += 1

            topic = data[key]['Topics'][1]
            
            if data[key]['gender'] is not None:
                for elements in data[key]['gender']:
                    if elements == 'm':
                        topics[topic]['male'] += 1
                    else:
                        topics[topic]['female'] += 1
            
    for key in topics.keys():
        if topics[key]['female'] == 0:
            topics[key]['ratio'] = None
            continue
        topics[key]['ratio'] = topics[key]['male']/topics[key]['female']
        
    total_male = 0; total_female = 0;
    for key in topics.keys():
        total_male += topics[key]['male']
        total_female += topics[key]['female']
    topics['Total'] = {'male': total_male, 'female': total_female, 'ratio': total_male/total_female}
    
    return topics

# %%
channel = "FOX"
CNN = topic_male_vs_female(channel)

# %% [markdown]
# # -1
# Ratio of each topic.

# %%
total = 0
for key in CNN.keys():
    if key == 'Foreign Policy' or key == 'Total':
        continue
    total += CNN[key]['count']
all_topics = ['Other', 'Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Climate']
all_ratios = []
plt.figure(figsize=(15,10))
for key in all_topics:
    all_ratios.append(CNN[key]['count']/total)
plt.subplot(1,2,1)
plt.pie(all_ratios, labels=all_topics);

all_topics = ['Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport',  'Climate']
total = 0
for key in all_topics:
    if key == 'Foreign Policy' or key == 'Total' or key == 'Other':
        continue
    total += CNN[key]['count']

all_ratios = []
for key in all_topics:
    all_ratios.append(CNN[key]['count']/total)
plt.subplot(1,2,2)
plt.pie(all_ratios, labels=all_topics);
plt.title('Wihtout Other');

# %% [markdown]
# # 0.
# Ratio in each topic, normalized by mean of the channel.
# PS : I think we need to normalize by each channel for data to be meaningful, happy to discuss if someone disagrees!

# %%
ratios = {}
all_topics = ['Other', 'Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Climate']
for topic in all_topics:
    ratios[topic] = {'male/total': 0}
all_ratios = []
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue    
    ratios[key]['male/total'] = CNN[key]['male']/(CNN[key]['male'] + CNN[key]['female'])
    print(key, ratios[key]['male/total'])
    all_ratios.append(ratios[key]['male/total'])
average = np.mean(all_ratios)
std = np.std(all_ratios)
all_ratios = []
for key in ratios.keys():
    all_ratios.append((ratios[key]['male/total'] - average)/np.sqrt(std))
idx = np.argsort(all_ratios)
plt.figure(figsize=(15, 10))
sns.barplot(np.arange(len(all_topics)), np.array(all_ratios)[idx])
plt.xticks(np.arange(len(all_topics)), np.array(all_topics)[idx], fontsize=15, rotation=45);
plt.title('Normalized Male/Total Ratio');

plt.figure(figsize=(15, 10))
sns.barplot(np.arange(len(all_topics)), np.array(all_ratios))
plt.xticks(np.arange(len(all_topics)), np.array(all_topics), fontsize=15, rotation=45);
plt.title('Normalized Male/Total Ratio');
# Out:
# Other 0.7043372819699655
# Politics 0.713206110503022
# Media 0.7115104419621175
# Fashion 0.7077658303464756
# Immigration 0.7159970388316845
# Economy 0.7150259067357513
# Health 0.7035654185948674
# Art 0.7064949089787103
# Gender 0.7181141928173802
# Sport 0.6978565921356977
# Climate 0.731487570695778

# %% [markdown]
# # 1.
# Male/(Male + Female) distribution. Question: Is it the case that it's mostly men, mostly women of it is usually mixed?

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(10,5))
    sns.kdeplot(CNN[key]['male_total_ratio'], label=key,
                                              color='r', shade=True)
    plt.legend(fontsize = 20)
    plt.xlabel("Male/Total ratio", fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlim([-0.5, 1.5])

# %% [markdown]
# # 2.
# Male/(Male + Female) distribution. Question: Is it the case that it's mostly men, mostly women of it is usually mixed?
#
# Same but now distribution is conditional on number of people >= 3: So when they are alot of people on the screen, how is the ratio?

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(10,5))
    sns.kdeplot(CNN[key]['conditional_male_total_ratio'], label=key,
                                              color='r', shade=True)
    plt.legend(fontsize = 20)
    plt.xlabel("Male/Total ratio", fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlim([-0.5, 1.5])

# %% [markdown]
# # 3.
# Distribution of number of male or female on the screen. (Not that interesting! :D)

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(15, 5))
    plt.subplot(1,2,1)
    sns.barplot([1, 2, 3, 4, 5], CNN[key]['male_number']/np.sum(CNN[key]['male_number']), label=key+'-male')
    plt.legend(fontsize=20)
    plt.subplot(1,2,2)
    sns.barplot([1, 2, 3, 4, 5], CNN[key]['female_number']/np.sum(CNN[key]['female_number']), label=key+'-female')
    plt.legend(fontsize=20)

# %% [markdown]
# # Topic Peoples
# **THIS HAS TO BE CHERRY PICKED IF WE WANNA TALK ABOUT IT**

# %%
def topic_people(channel):
    topics = {}
    for topic in ['Other', 'Politics', 'Media', 'Fashion', 'Foreign Policy', 'Immigration', 
         'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Violence', 'Climate']:
        topics[topic] = {}
    all_files = glob.glob('processed_data/%s/*.p'%channel)
    
    for file in all_files:
        data = pickle.load(open(file, 'rb'))
        for key in data.keys():
            topic = data[key]['Topics'][0]
            if data[key]['persons'] is not None:
                persons = data[key]['persons']
                for person in persons:
                    if person in topics[topic].keys():
                        topics[topic][person] += 1
                    else:
                        topics[topic][person] = 1
    
    return topics

# %%
CNN_Topics = topic_people(channel)

# %%
for key in CNN_Topics.keys():
    CNN_Topics[key] = sorted(CNN_Topics[key].items(), key=operator.itemgetter(1), reverse=True)

# %%
for key in CNN_Topics.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    print("============= " + key + " =============")
    print(CNN_Topics[key][:50])
    print("=============")
# Out:
# ============= Other =============
# [("bill o'reilly", 1518), ('anderson cooper', 1295), ('sean hannity', 1106), ('barack obama', 1051), ('greg gutfeld', 958), ('neil cavuto', 956), ('megyn kelly', 896), ('greta van susteren', 764), ('mike huckabee', 758), ('glenn beck', 673), ('don lemon', 590), ('shepard smith', 493), ('jeanine pirro', 485), ('bret baier', 479), ('bob beckel', 463), ('dana perino', 452), ('eric bolling', 442), ('juan williams', 415), ('martha maccallum', 397), ('charles krauthammer', 397), ('chris wallace', 394), ('wolf blitzer', 384), ('laura ingraham', 370), ('tucker carlson', 369), ('piers morgan', 355), ('brian kilmeade', 345), ('brooke baldwin', 339), ('andrew levy', 336), ('erin burnett', 320), ('fredricka whitfield', 308), ('karl rove', 295), ('john king', 294), ('geraldo rivera', 287), ('kimberly guilfoyle', 286), ('shannon bream', 286), ('steve doocy', 284), ('ali velshi', 284), ('donald trump', 282), ('bill hemmer', 278), ('gretchen carlson', 276), ('andrea tantaros', 272), ('ed henry', 272), ('harris faulkner', 247), ('mitt romney', 236), ('newt gingrich', 231), ('christine romans', 219), ('john berman', 212), ('john r. bolton', 204), ('jon scott', 202), ('brit hume', 200)]
# =============
# ============= Politics =============
# [("bill o'reilly", 946), ('anderson cooper', 718), ('sean hannity', 712), ('barack obama', 660), ('neil cavuto', 579), ('greg gutfeld', 576), ('megyn kelly', 527), ('mike huckabee', 502), ('greta van susteren', 441), ('glenn beck', 415), ('brian kilmeade', 301), ('eric bolling', 295), ('don lemon', 290), ('bob beckel', 288), ('shepard smith', 282), ('jeanine pirro', 282), ('bret baier', 273), ('dana perino', 257), ('laura ingraham', 244), ('martha maccallum', 243), ('karl rove', 240), ('tucker carlson', 235), ('piers morgan', 215), ('wolf blitzer', 206), ('chris wallace', 204), ('steve doocy', 202), ('juan williams', 200), ('donald trump', 198), ('andrew levy', 194), ('fredricka whitfield', 190), ('gretchen carlson', 186), ('ed henry', 184), ('newt gingrich', 180), ('brooke baldwin', 172), ('shannon bream', 168), ('erin burnett', 161), ('mitt romney', 158), ('jon scott', 158), ('andrea tantaros', 157), ('ali velshi', 155), ('stuart varney', 154), ('john king', 152), ('geraldo rivera', 149), ('bill hemmer', 145), ('harris faulkner', 143), ('charles krauthammer', 142), ('kimberly guilfoyle', 137), ('brit hume', 136), ('dana bash', 135), ('rick santorum', 135)]
# =============
# ============= Media =============
# [("bill o'reilly", 132), ('anderson cooper', 125), ('barack obama', 120), ('sean hannity', 113), ('greg gutfeld', 110), ('neil cavuto', 103), ('megyn kelly', 92), ('greta van susteren', 80), ('mike huckabee', 77), ('bob beckel', 69), ('eric bolling', 68), ('glenn beck', 66), ('don lemon', 65), ('dana perino', 56), ('karl rove', 55), ('shepard smith', 55), ('brian kilmeade', 54), ('martha maccallum', 50), ('jeanine pirro', 47), ('piers morgan', 46), ('stuart varney', 43), ('donald trump', 41), ('wolf blitzer', 41), ('chris wallace', 40), ('bret baier', 40), ('brit hume', 39), ('laura ingraham', 38), ('newt gingrich', 38), ('juan williams', 37), ('tucker carlson', 37), ('steve doocy', 35), ('mitt romney', 33), ('fredricka whitfield', 32), ('ed henry', 31), ('brooke baldwin', 30), ('erin burnett', 30), ('gretchen carlson', 30), ('john king', 30), ('john berman', 28), ('charles krauthammer', 28), ('harris faulkner', 28), ('rick santorum', 27), ('sanjay gupta', 27), ('dick morris', 26), ('ali velshi', 26), ('bill hemmer', 26), ('andrea tantaros', 24), ('shannon bream', 23), ('david gergen', 23), ('heather childers', 23)]
# =============
# ============= Fashion =============
# [('martha maccallum', 6), ('barack obama', 5), ('anderson cooper', 5), ('megyn kelly', 5), ('glenn beck', 4), ("bill o'reilly", 4), ('greta van susteren', 4), ('gretchen carlson', 3), ('geraldo rivera', 2), ('laura ingraham', 2), ('ron paul', 2), ('byron york', 2), ('paul gigot', 2), ('greg gutfeld', 2), ('shepard smith', 2), ('neil cavuto', 2), ('shannon bream', 2), ('tucker carlson', 2), ('laura bush', 1), ('john barrasso', 1), ('michael hayden', 1), ('tina knowles', 1), ('moxiie', 1), ('gerard butler', 1), ('larry the cable guy', 1), ('jamal anderson', 1), ('reince priebus', 1), ('queen sonja of norway', 1), ('john boehner', 1), ('david chalian', 1), ('paul lisicky', 1), ('jim acosta', 1), ('géza szőcs', 1), ('jo brand', 1), ('annaleigh ashford', 1), ('r. james woolsey jr.', 1), ('dana milbank', 1), ('marek sapara', 1), ('ari fleischer', 1), ('dana perino', 1), ('chris christie', 1), ('kevin mccarthy', 1), ('karl rove', 1), ('eric adams', 1), ('john berman', 1), ('rick santorum', 1), ('robert gibbs', 1), ('jackie speier', 1), ('brianna keilar', 1), ('andrea tantaros', 1)]
# =============
# ============= Immigration =============
# [("bill o'reilly", 184), ('anderson cooper', 147), ('barack obama', 125), ('sean hannity', 105), ('greta van susteren', 97), ('greg gutfeld', 94), ('megyn kelly', 86), ('mike huckabee', 86), ('neil cavuto', 80), ('glenn beck', 76), ('don lemon', 55), ('dana perino', 54), ('shepard smith', 50), ('eric bolling', 48), ('wolf blitzer', 45), ('bret baier', 44), ('jeanine pirro', 42), ('bob beckel', 40), ('mitt romney', 40), ('john r. bolton', 39), ('chris wallace', 39), ('tucker carlson', 37), ('martha maccallum', 36), ('brian kilmeade', 36), ('laura ingraham', 36), ('juan williams', 35), ('erin burnett', 34), ('brit hume', 33), ('donald trump', 33), ('karl rove', 32), ('brooke baldwin', 31), ('fredricka whitfield', 30), ('sarah palin', 29), ('piers morgan', 28), ('andrea tantaros', 27), ('jon scott', 25), ('steve doocy', 25), ('geraldo rivera', 25), ('ali velshi', 24), ('ed henry', 24), ('bill hemmer', 24), ('gretchen carlson', 24), ('shannon bream', 23), ('andrew levy', 23), ('newt gingrich', 22), ('stuart varney', 22), ('john mccain', 21), ('jake tapper', 20), ('sanjay gupta', 20), ('rand paul', 20)]
# =============
# ============= Economy =============
# [('barack obama', 7), ('martha maccallum', 7), ('megyn kelly', 5), ('brian kilmeade', 5), ('gretchen carlson', 4), ('tucker carlson', 4), ('anderson cooper', 3), ('jon scott', 3), ('steve doocy', 3), ('t. j. holmes', 2), ('chris cuomo', 2), ('david petraeus', 2), ('ali velshi', 2), ('medina', 2), ('john r. bolton', 2), ('clayton morris', 2), ('eric bolling', 2), ('francisca valenzuela', 2), ('william devane', 2), ('william binney', 2), ('hamid karzai', 2), ('heather childers', 2), ('jamie colby', 2), ('john roberts', 1), ('william kristol', 1), ('michael ray', 1), ('chen guangcheng', 1), ('jessica yellin', 1), ('dariusz wdowczyk', 1), ('mýa', 1), ('john king', 1), ('monica crowley', 1), ('don lemon', 1), ('joe biden', 1), ('ed henry', 1), ('kristen welker', 1), ('adam hughes', 1), ('julian assange', 1), ('samuli edelmann', 1), ('michael hogan', 1), ('angela corey', 1), ('alan dershowitz', 1), ('louie gohmert', 1), ('olympia snowe', 1), ('gayle tzemach lemmon', 1), ('elizabeth cohen', 1), ('dan lothian', 1), ('alice ghostley', 1), ('gloria scott', 1), ('stephen f. hayes', 1)]
# =============
# ============= Health =============
# [("bill o'reilly", 178), ('anderson cooper', 136), ('sean hannity', 116), ('greg gutfeld', 109), ('neil cavuto', 101), ('barack obama', 92), ('megyn kelly', 74), ('mike huckabee', 59), ('greta van susteren', 58), ('don lemon', 55), ('juan williams', 52), ('eric bolling', 50), ('shepard smith', 47), ('bret baier', 47), ('jeanine pirro', 46), ('laura ingraham', 46), ('dana perino', 44), ('glenn beck', 43), ('piers morgan', 42), ('chris wallace', 41), ('tucker carlson', 39), ('wolf blitzer', 37), ('bob beckel', 37), ('erin burnett', 37), ('charles krauthammer', 36), ('brooke baldwin', 33), ('karl rove', 33), ('geraldo rivera', 30), ('ali velshi', 29), ('martha maccallum', 28), ('kimberly guilfoyle', 28), ('john king', 27), ('brian kilmeade', 27), ('andrew levy', 26), ('stuart varney', 24), ('christine romans', 24), ('donald trump', 24), ('bill hemmer', 23), ('mitt romney', 23), ('david gergen', 23), ('shannon bream', 22), ('john stossel', 22), ('sanjay gupta', 22), ('newt gingrich', 22), ('fredricka whitfield', 21), ('dana bash', 20), ('john r. bolton', 20), ('gretchen carlson', 19), ('steve doocy', 19), ('t. j. holmes', 19)]
# =============
# ============= Art =============
# [('anderson cooper', 50), ('greg gutfeld', 49), ("bill o'reilly", 49), ('sean hannity', 46), ('neil cavuto', 42), ('barack obama', 37), ('megyn kelly', 33), ('greta van susteren', 31), ('glenn beck', 31), ('chris wallace', 26), ('karl rove', 24), ('don lemon', 23), ('laura ingraham', 22), ('bret baier', 21), ('bob beckel', 20), ('wolf blitzer', 19), ('jeanine pirro', 19), ('eric bolling', 18), ('mike huckabee', 18), ('shepard smith', 18), ('brian kilmeade', 18), ('steve doocy', 17), ('dana perino', 17), ('piers morgan', 16), ('donald trump', 16), ('martha maccallum', 15), ('tucker carlson', 14), ('bill hemmer', 14), ('ali velshi', 14), ('fredricka whitfield', 13), ('mitt romney', 13), ('juan williams', 12), ('ed henry', 12), ('andrea tantaros', 12), ('shannon bream', 12), ('geraldo rivera', 11), ('john berman', 10), ('kimberly guilfoyle', 10), ('erin burnett', 10), ('gretchen carlson', 10), ('brooke baldwin', 9), ('candy crowley', 9), ('brit hume', 9), ('jason chaffetz', 9), ('leslie marshall', 8), ('monica crowley', 8), ('john r. bolton', 8), ('john king', 8), ('john roberts', 8), ('kirsten powers', 8)]
# =============
# ============= Gender =============
# [("bill o'reilly", 27), ('sean hannity', 23), ('greg gutfeld', 18), ('anderson cooper', 18), ('barack obama', 16), ('greta van susteren', 15), ('neil cavuto', 15), ('megyn kelly', 11), ('wolf blitzer', 11), ('mike huckabee', 11), ('don lemon', 10), ('jeanine pirro', 8), ('john mccain', 7), ('martha maccallum', 7), ('ed henry', 7), ('bret baier', 7), ('eric bolling', 6), ('donald trump', 6), ('jim acosta', 6), ('bill hemmer', 6), ('catherine herridge', 6), ('ali velshi', 6), ('t. j. holmes', 5), ('heather childers', 5), ('rick santorum', 5), ('steve doocy', 5), ('dana bash', 5), ('randi kaye', 5), ('glenn beck', 5), ('mitt romney', 5), ('shepard smith', 5), ('chris wallace', 4), ('jon scott', 4), ('brooke baldwin', 4), ('lindsey graham', 4), ('kevin mccarthy', 4), ('tucker carlson', 4), ('kate bolduan', 4), ('carl cameron', 4), ('christine romans', 4), ('bob beckel', 4), ('john berman', 4), ('piers morgan', 4), ('heather nauert', 4), ('erin burnett', 4), ('brian kilmeade', 4), ('geraldo rivera', 4), ('stuart varney', 4), ('john king', 4), ('jay carney', 3)]
# =============
# ============= Sport =============
# [("bill o'reilly", 295), ('anderson cooper', 229), ('sean hannity', 196), ('barack obama', 187), ('greg gutfeld', 172), ('neil cavuto', 166), ('megyn kelly', 155), ('greta van susteren', 147), ('mike huckabee', 123), ('glenn beck', 122), ('don lemon', 113), ('bob beckel', 88), ('karl rove', 81), ('juan williams', 81), ('chris wallace', 81), ('shepard smith', 78), ('charles krauthammer', 75), ('dana perino', 73), ('bill hemmer', 72), ('laura ingraham', 72), ('bret baier', 70), ('eric bolling', 68), ('jeanine pirro', 68), ('piers morgan', 64), ('wolf blitzer', 64), ('brooke baldwin', 60), ('erin burnett', 59), ('harris faulkner', 57), ('gretchen carlson', 55), ('martha maccallum', 55), ('tucker carlson', 54), ('brian kilmeade', 53), ('donald trump', 51), ('fredricka whitfield', 51), ('shannon bream', 50), ('geraldo rivera', 49), ('newt gingrich', 48), ('brit hume', 46), ('kimberly guilfoyle', 46), ('mitt romney', 46), ('john berman', 44), ('john king', 43), ('john r. bolton', 42), ('ali velshi', 42), ('steve doocy', 40), ('rick santorum', 39), ('andrea tantaros', 38), ('john stossel', 36), ('mary katharine ham', 36), ('randi kaye', 34)]
# =============
# ============= Climate =============
# [("bill o'reilly", 271), ('barack obama', 251), ('anderson cooper', 230), ('sean hannity', 199), ('neil cavuto', 148), ('greg gutfeld', 146), ('mike huckabee', 142), ('megyn kelly', 114), ('glenn beck', 110), ('don lemon', 103), ('greta van susteren', 93), ('jeanine pirro', 91), ('wolf blitzer', 76), ('shepard smith', 72), ('andrew levy', 71), ('donald trump', 69), ('bret baier', 68), ('piers morgan', 65), ('eric bolling', 65), ('laura ingraham', 63), ('ed henry', 61), ('john king', 55), ('erin burnett', 55), ('brian kilmeade', 55), ('shannon bream', 55), ('mitt romney', 49), ('newt gingrich', 48), ('martha maccallum', 46), ('brooke baldwin', 44), ('chris wallace', 44), ('bill hemmer', 44), ('karl rove', 42), ('dana perino', 41), ('jon scott', 40), ('mike emanuel', 39), ('tucker carlson', 39), ('ali velshi', 36), ('fredricka whitfield', 36), ('bob beckel', 35), ('sarah palin', 35), ('gretchen carlson', 34), ('andrea tantaros', 34), ('catherine herridge', 34), ('fareed zakaria', 33), ('stuart varney', 33), ('christine romans', 32), ('sanjay gupta', 29), ('dana bash', 28), ('t. j. holmes', 28), ('steve doocy', 28)]
# =============
