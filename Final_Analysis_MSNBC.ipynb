# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import pickle
from tqdm import tqdm
import operator

sns.set()

# %matplotlib inline

# %% [markdown]
# ### Topic: Male vs. Female

# %%
def topic_male_vs_female(channel):
    topics = {}
    for topic in ['Other', 'Politics', 'Media', 'Fashion', 'Foreign Policy', 'Immigration', 
         'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Violence', 'Climate']:
        topics[topic] = {'count': 0, 'male': 0, 'female': 0, 'ratio': 0,
                         'male_number': [0, 0, 0, 0, 0], 'female_number': [0, 0, 0, 0, 0],
                        'male_total_ratio': [], 'conditional_male_total_ratio': []} #1, 2, 3, 4, 5
    
    all_files = glob.glob('processed_data/%s/*.p'%channel)
    
    for file in all_files:
        data = pickle.load(open(file, 'rb'))
        for key in data.keys():
            topic = data[key]['Topics'][0]
            topics[topic]['count'] += 1
            if data[key]['gender'] is not None:
                for elements in data[key]['gender']:
                    if elements == 'm':
                        topics[topic]['male'] += 1
                    else:
                        topics[topic]['female'] += 1

                all_genders = np.array(data[key]['gender'])
                num_men = all_genders[all_genders=='m'].shape[0]
                num_female = all_genders[all_genders=='f'].shape[0]
                topics[topic]['male_total_ratio'].append(num_men/(num_men + num_female))
                if num_men + num_female >= 3:
                    topics[topic]['conditional_male_total_ratio'].append(num_men/(num_men + num_female))
                if len(all_genders) == 1:
                        continue
                if num_men > 0:
                    num_men = min(num_men-1, 4)
                    topics[topic]['male_number'][num_men] += 1
                if num_female > 0:
                    num_female = min(num_female-1, 4)
                    topics[topic]['female_number'][num_female] += 1

            topic = data[key]['Topics'][1]
            
            if data[key]['gender'] is not None:
                for elements in data[key]['gender']:
                    if elements == 'm':
                        topics[topic]['male'] += 1
                    else:
                        topics[topic]['female'] += 1
            
    for key in topics.keys():
        if topics[key]['female'] == 0:
            topics[key]['ratio'] = None
            continue
        topics[key]['ratio'] = topics[key]['male']/topics[key]['female']
        
    total_male = 0; total_female = 0;
    for key in topics.keys():
        total_male += topics[key]['male']
        total_female += topics[key]['female']
    topics['Total'] = {'male': total_male, 'female': total_female, 'ratio': total_male/total_female}
    
    return topics

# %%
channel = "MSNBC"
CNN = topic_male_vs_female(channel)

# %% [markdown]
# # -1
# Ratio of each topic.

# %%
total = 0
for key in CNN.keys():
    if key == 'Foreign Policy' or key == 'Total':
        continue
    total += CNN[key]['count']
all_topics = ['Other', 'Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Climate']
all_ratios = []
plt.figure(figsize=(15,10))
for key in all_topics:
    all_ratios.append(CNN[key]['count']/total)
plt.subplot(1,2,1)
plt.pie(all_ratios, labels=all_topics);

all_topics = ['Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport',  'Climate']
total = 0
for key in all_topics:
    if key == 'Foreign Policy' or key == 'Total' or key == 'Other':
        continue
    total += CNN[key]['count']

all_ratios = []
for key in all_topics:
    all_ratios.append(CNN[key]['count']/total)
plt.subplot(1,2,2)
plt.pie(all_ratios, labels=all_topics);
plt.title('Wihtout Other');

# %% [markdown]
# # 0.
# Ratio in each topic, normalized by mean of the channel.
# PS : I think we need to normalize by each channel for data to be meaningful, happy to discuss if someone disagrees!

# %%
ratios = {}
all_topics = ['Other', 'Politics', 'Media', 'Fashion', 'Immigration', 
     'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Climate']
for topic in all_topics:
    ratios[topic] = {'male/total': 0}
all_ratios = []
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue    
    ratios[key]['male/total'] = CNN[key]['male']/(CNN[key]['male'] + CNN[key]['female'])
    print(key, ratios[key]['male/total'])
    all_ratios.append(ratios[key]['male/total'])
average = np.mean(all_ratios)
std = np.std(all_ratios)
all_ratios = []
for key in ratios.keys():
    all_ratios.append((ratios[key]['male/total'] - average)/np.sqrt(std))
idx = np.argsort(all_ratios)
plt.figure(figsize=(15, 10))
sns.barplot(np.arange(len(all_topics)), np.array(all_ratios)[idx])
plt.xticks(np.arange(len(all_topics)), np.array(all_topics)[idx], fontsize=15, rotation=45);
plt.title('Normalized Male/Total Ratio');

plt.figure(figsize=(15, 10))
sns.barplot(np.arange(len(all_topics)), np.array(all_ratios))
plt.xticks(np.arange(len(all_topics)), np.array(all_topics), fontsize=15, rotation=45);
plt.title('Normalized Male/Total Ratio');
# Out:
# Other 0.7084603762470205
# Politics 0.7180436426206429
# Media 0.7133006713845037
# Fashion 0.7050180831826401
# Immigration 0.7145961820851688
# Economy 0.7286512370311253
# Health 0.704805114456589
# Art 0.7072733098365909
# Gender 0.7284670223736717
# Sport 0.7025412231266959
# Climate 0.7402337646102881

# %% [markdown]
# # 1.
# Male/(Male + Female) distribution. Question: Is it the case that it's mostly men, mostly women of it is usually mixed?

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(10,5))
    sns.kdeplot(CNN[key]['male_total_ratio'], label=key,
                                              color='r', shade=True)
    plt.legend(fontsize = 20)
    plt.xlabel("Male/Total ratio", fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlim([-0.5, 1.5])

# %% [markdown]
# # 2.
# Male/(Male + Female) distribution. Question: Is it the case that it's mostly men, mostly women of it is usually mixed?
#
# Same but now distribution is conditional on number of people >= 3: So when they are alot of people on the screen, how is the ratio?

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(10,5))
    sns.kdeplot(CNN[key]['conditional_male_total_ratio'], label=key,
                                              color='r', shade=True)
    plt.legend(fontsize = 20)
    plt.xlabel("Male/Total ratio", fontsize=20)
    plt.xticks(fontsize=20)
    plt.xlim([-0.5, 1.5])

# %% [markdown]
# # 3.
# Distribution of number of male or female on the screen. (Not that interesting! :D)

# %%
for key in CNN.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    plt.figure(figsize=(15, 5))
    plt.subplot(1,2,1)
    sns.barplot([1, 2, 3, 4, 5], CNN[key]['male_number']/np.sum(CNN[key]['male_number']), label=key+'-male')
    plt.legend(fontsize=20)
    plt.subplot(1,2,2)
    sns.barplot([1, 2, 3, 4, 5], CNN[key]['female_number']/np.sum(CNN[key]['female_number']), label=key+'-female')
    plt.legend(fontsize=20)

# %% [markdown]
# # Topic Peoples
# **THIS HAS TO BE CHERRY PICKED IF WE WANNA TALK ABOUT IT**

# %%
def topic_people(channel):
    topics = {}
    for topic in ['Other', 'Politics', 'Media', 'Fashion', 'Foreign Policy', 'Immigration', 
         'Economy', 'Health', 'Art', 'Gender', 'Sport', 'Violence', 'Climate']:
        topics[topic] = {}
    all_files = glob.glob('processed_data/%s/*.p'%channel)
    
    for file in all_files:
        data = pickle.load(open(file, 'rb'))
        for key in data.keys():
            topic = data[key]['Topics'][0]
            if data[key]['persons'] is not None:
                persons = data[key]['persons']
                for person in persons:
                    if person in topics[topic].keys():
                        topics[topic][person] += 1
                    else:
                        topics[topic][person] = 1
    
    return topics

# %%
CNN_Topics = topic_people(channel)

# %%
for key in CNN_Topics.keys():
    CNN_Topics[key] = sorted(CNN_Topics[key].items(), key=operator.itemgetter(1), reverse=True)

# %%
for key in CNN_Topics.keys():
    if key == 'Total' or key == 'Foreign Policy' or key == 'Violence':
        continue
    print("============= " + key + " =============")
    print(CNN_Topics[key][:50])
    print("=============")
# Out:
# ============= Other =============
# [('chris matthews', 1889), ('barack obama', 1732), ('rachel maddow', 1555), ('ed schultz', 1113), ("lawrence o'donnell", 987), ('chris hayes', 888), ('donald trump', 765), ('chuck todd', 697), ('anderson cooper', 639), ('chris cuomo', 635), ('don lemon', 575), ('joe scarborough', 519), ('andrea mitchell', 513), ('mitt romney', 458), ('al sharpton', 448), ('tucker carlson', 448), ('sean hannity', 443), ('john berman', 407), ('mika brzezinski', 356), ('willie geist', 346), ('tamron hall', 344), ('chris jansing', 337), ('steve kornacki', 335), ('ari melber', 330), ('david gregory', 328), ('alex wagner', 312), ('alex witt', 295), ('anthony bourdain', 288), ('thomas roberts', 283), ('laura ingraham', 278), ('howard fineman', 274), ('shannon bream', 262), ('michael smerconish', 260), ('melissa harris-perry', 259), ('keith olbermann', 259), ('joy-ann reid', 258), ('michael steele', 257), ('john boehner', 257), ('brooke baldwin', 254), ('joe biden', 249), ('david corn', 245), ('karen finney', 234), ('erin burnett', 231), ('dylan ratigan', 228), ('eugene robinson', 223), ('martin bashir', 221), ('christopher michael cillizza', 217), ('newt gingrich', 216), ('ezra klein', 215), ('chris christie', 208)]
# =============
# ============= Politics =============
# [('barack obama', 1076), ('chris matthews', 924), ('rachel maddow', 859), ('ed schultz', 709), ("lawrence o'donnell", 573), ('chris hayes', 450), ('donald trump', 448), ('chuck todd', 422), ('chris cuomo', 355), ('don lemon', 335), ('anderson cooper', 323), ('mitt romney', 309), ('joe scarborough', 305), ('andrea mitchell', 294), ('sean hannity', 257), ('tucker carlson', 253), ('al sharpton', 247), ('mika brzezinski', 207), ('willie geist', 207), ('john berman', 199), ('steve kornacki', 192), ('david gregory', 190), ('howard fineman', 188), ('david corn', 180), ('john boehner', 178), ('chris jansing', 177), ('thomas roberts', 177), ('tamron hall', 173), ('ari melber', 160), ('brooke baldwin', 151), ('michael smerconish', 151), ('anthony bourdain', 151), ('alex wagner', 150), ('melissa harris-perry', 150), ('laura ingraham', 149), ('joy-ann reid', 149), ('kristen welker', 144), ('alex witt', 138), ('john mccain', 134), ('martin bashir', 132), ('joe biden', 131), ('christopher michael cillizza', 127), ('greg gutfeld', 125), ('dylan ratigan', 124), ('martha maccallum', 122), ('eugene robinson', 121), ('newt gingrich', 120), ('michael steele', 119), ('karen finney', 118), ('jeanine pirro', 115)]
# =============
# ============= Media =============
# [('chris matthews', 206), ('barack obama', 179), ('rachel maddow', 160), ('ed schultz', 137), ('chuck todd', 95), ('chris hayes', 94), ("lawrence o'donnell", 92), ('donald trump', 75), ('chris cuomo', 70), ('don lemon', 64), ('anderson cooper', 63), ('andrea mitchell', 57), ('mitt romney', 56), ('howard fineman', 55), ('tucker carlson', 52), ('joe scarborough', 52), ('sean hannity', 51), ('david gregory', 49), ('david corn', 46), ('willie geist', 44), ('john berman', 44), ('al sharpton', 44), ('mika brzezinski', 43), ('tamron hall', 42), ('laura ingraham', 35), ('shannon bream', 34), ('thomas roberts', 34), ('michael smerconish', 33), ('martha maccallum', 31), ('michael steele', 30), ('erin burnett', 30), ('alex wagner', 30), ('ari melber', 29), ('steve kornacki', 29), ('melissa harris-perry', 29), ('ed rendell', 29), ('chris christie', 28), ('chris jansing', 28), ('joy-ann reid', 26), ('jonathan capehart', 26), ('joe biden', 25), ('anthony bourdain', 24), ('ezra klein', 24), ('jeffrey toobin', 24), ('kristen welker', 23), ('newt gingrich', 23), ('keith olbermann', 23), ('christopher michael cillizza', 23), ('jim sciutto', 23), ('krystal ball', 23)]
# =============
# ============= Fashion =============
# [('chris matthews', 9), ('barack obama', 5), ("lawrence o'donnell", 4), ('willie geist', 4), ('rachel maddow', 3), ('chris jansing', 3), ('christopher michael cillizza', 3), ('van jones', 3), ('chris christie', 2), ('savannah guthrie', 2), ('joe scarborough', 2), ('pete williams', 2), ('donald trump', 2), ('orrin hatch', 2), ('thomas roberts', 2), ('john f. kennedy', 2), ('michael steele', 2), ('melissa harris-perry', 2), ('andrea mitchell', 2), ('nancy pelosi', 2), ('chris hayes', 2), ('sean hannity', 2), ('rand paul', 2), ('rich eisen', 1), ('barney frank', 1), ('patrick murphy', 1), ('lionnel luca', 1), ('ari melber', 1), ("shaquille o'neal", 1), ('lawrence s. stroll', 1), ('michał urbaniak', 1), ('ellen ochoa', 1), ('anthony bourdain', 1), ('robert w. service', 1), ('anita decker breckenridge', 1), ('don lemon', 1), ('michele bachmann', 1), ('david gregory', 1), ('austan goolsbee', 1), ('ayman mohyeldin', 1), ('richard madeley', 1), ('jillian barberie', 1), ('figen yüksekdağ', 1), ('matt gaetz', 1), ('keith olbermann', 1), ('mark kirk', 1), ('susan page', 1), ('alex witt', 1), ('ryan lizza', 1), ('kelley armstrong', 1)]
# =============
# ============= Immigration =============
# [('chris matthews', 203), ('barack obama', 191), ('rachel maddow', 162), ('ed schultz', 115), ('chris hayes', 98), ("lawrence o'donnell", 88), ('donald trump', 85), ('anderson cooper', 72), ('chuck todd', 69), ('joe scarborough', 69), ('chris cuomo', 63), ('sean hannity', 62), ('andrea mitchell', 60), ('mika brzezinski', 56), ('al sharpton', 54), ('don lemon', 52), ('david gregory', 51), ('david corn', 44), ('ari melber', 43), ('mitt romney', 42), ('howard fineman', 38), ('alex wagner', 38), ('thomas roberts', 37), ('tucker carlson', 37), ('joe biden', 36), ('michael steele', 36), ('john berman', 34), ('steve kornacki', 34), ('anthony bourdain', 33), ('eugene robinson', 32), ('keith olbermann', 31), ('chris jansing', 30), ('kristen welker', 30), ('joy-ann reid', 30), ('tamron hall', 29), ('willie geist', 29), ('shannon bream', 29), ('laura ingraham', 28), ('john boehner', 28), ('melissa harris-perry', 27), ('alex witt', 25), ('chris christie', 24), ('ayman mohyeldin', 24), ('ed rendell', 24), ('ashleigh banfield', 23), ('mark halperin', 23), ('jonathan capehart', 23), ('erin burnett', 23), ('christopher michael cillizza', 23), ('neil cavuto', 22)]
# =============
# ============= Economy =============
# [('joe scarborough', 4), ('mika brzezinski', 3), ('mark halperin', 2), ('valerie jarrett', 2), ('jonathan capehart', 2), ('paul ryan', 1), ('chris cuomo', 1), ('drake', 1), ('charles payne', 1), ('barack obama', 1), ('brian williams', 1), ('alex wagner', 1), ("robert ri'chard", 1), ('sarah shahi', 1), ('don lemon', 1), ('richard n. haass', 1), ('rachel maddow', 1), ('krzysztof piątek', 1), ('frank bruni', 1), ('luke russert', 1), ('kim coles', 1), ('jordi cañas pérez', 1), ('pete gardner', 1), ('maria timmer', 1), ("lawrence o'donnell", 1), ('craig charles', 1), ('hallie jackson', 1), ('chris matthews', 1), ('michael skolnik', 1), ('jemele hill', 1), ('steven levitan', 1), ('eugene robinson', 1), ('martin tyler', 1), ('bernard rapp', 1), ('steve kornacki', 1), ('karen carney', 1), ('bernie sanders', 1), ('jay mcinerney', 1), ('anthony bourdain', 1), ('michael steele', 1), ('dequina moore', 1), ('anthony weiner', 1), ('patrick mcloughlin', 1), ('jeff tremaine', 1), ('mortimer zuckerman', 1), ('chris hayes', 1), ('ed rendell', 1), ('chuck todd', 1), ('josé ángel gurría', 1), ('natalie tennant', 1)]
# =============
# ============= Health =============
# [('chris matthews', 236), ('barack obama', 174), ('rachel maddow', 157), ("lawrence o'donnell", 117), ('ed schultz', 109), ('chris hayes', 89), ('donald trump', 79), ('don lemon', 66), ('chuck todd', 64), ('andrea mitchell', 62), ('joe scarborough', 60), ('chris cuomo', 57), ('anderson cooper', 57), ('al sharpton', 55), ('tucker carlson', 52), ('mitt romney', 49), ('ari melber', 46), ('john berman', 43), ('mika brzezinski', 42), ('chris jansing', 42), ('alex wagner', 40), ('alex witt', 40), ('anthony bourdain', 39), ('tamron hall', 37), ('steve kornacki', 37), ('christopher michael cillizza', 37), ('sean hannity', 36), ('howard fineman', 36), ('joy-ann reid', 32), ('michael smerconish', 32), ('laura ingraham', 31), ('david corn', 31), ('eugene robinson', 28), ('ashleigh banfield', 27), ('keith olbermann', 27), ('jonathan capehart', 27), ('david gregory', 27), ('john boehner', 26), ('karen finney', 26), ('michael steele', 26), ('brooke baldwin', 25), ('dylan ratigan', 25), ('thomas roberts', 25), ('willie geist', 24), ('newt gingrich', 23), ('joe biden', 23), ('paul ryan', 23), ('fredricka whitfield', 22), ('melissa harris-perry', 22), ('greg gutfeld', 22)]
# =============
# ============= Art =============
# [('chris matthews', 68), ('rachel maddow', 54), ('barack obama', 52), ('chris hayes', 45), ('ed schultz', 41), ('joe scarborough', 33), ('chuck todd', 33), ("lawrence o'donnell", 29), ('mika brzezinski', 26), ('don lemon', 25), ('andrea mitchell', 22), ('howard fineman', 22), ('anderson cooper', 22), ('sean hannity', 19), ('willie geist', 18), ('tucker carlson', 18), ('al sharpton', 17), ('donald trump', 17), ('chris cuomo', 17), ('david gregory', 16), ('john berman', 16), ('steve kornacki', 15), ('joy-ann reid', 14), ('alex witt', 14), ('michael steele', 14), ('ari melber', 14), ('david corn', 13), ('mitt romney', 12), ('eugene robinson', 12), ('hillary clinton', 12), ('ayman mohyeldin', 12), ('peter alexander', 12), ('laura ingraham', 11), ('anthony bourdain', 11), ('krystal ball', 11), ('shannon bream', 11), ('mark halperin', 10), ('elizabeth warren', 10), ('jeffrey toobin', 10), ('tamron hall', 10), ('ezra klein', 9), ('kristen welker', 9), ('brooke baldwin', 9), ('martha maccallum', 9), ('john heilemann', 9), ('chris jansing', 9), ('robert mueller', 9), ('alex wagner', 9), ('brian kilmeade', 8), ('ainsley earhardt', 8)]
# =============
# ============= Gender =============
# [('barack obama', 27), ("lawrence o'donnell", 19), ('donald trump', 15), ('chris matthews', 14), ('rachel maddow', 13), ('ed schultz', 13), ('chris cuomo', 12), ('chris hayes', 12), ('sean hannity', 11), ('john boehner', 11), ('kristen welker', 11), ('don lemon', 10), ('chuck todd', 10), ('david gregory', 9), ('al sharpton', 9), ('john mccain', 8), ('howard fineman', 8), ('christopher michael cillizza', 7), ('mitt romney', 7), ('steve kornacki', 7), ('john berman', 7), ('anderson cooper', 6), ('eric cantor', 6), ('pete williams', 6), ('andrea mitchell', 6), ('michael smerconish', 6), ('brooke baldwin', 6), ('chris jansing', 6), ('hallie jackson', 5), ('jesse watters', 5), ('tamron hall', 5), ('ed rendell', 5), ('mika brzezinski', 4), ('tucker carlson', 4), ('contessa brewer', 4), ('peter alexander', 4), ('alex witt', 4), ('brian kilmeade', 4), ('alex wagner', 4), ('laura ingraham', 4), ('brianna keilar', 4), ('chris christie', 4), ('dylan ratigan', 4), ('rudy giuliani', 3), ('steven rattner', 3), ('jeanine pirro', 3), ('mike viqueira', 3), ('thomas roberts', 3), ('bret baier', 3), ('newt gingrich', 3)]
# =============
# ============= Sport =============
# [('chris matthews', 349), ('rachel maddow', 279), ('barack obama', 263), ('ed schultz', 192), ("lawrence o'donnell", 166), ('chris hayes', 138), ('anderson cooper', 122), ('donald trump', 113), ('joe scarborough', 112), ('andrea mitchell', 108), ('don lemon', 107), ('chuck todd', 104), ('sean hannity', 99), ('al sharpton', 92), ('mitt romney', 81), ('chris cuomo', 79), ('mika brzezinski', 72), ('david gregory', 70), ('alex wagner', 64), ('tucker carlson', 64), ('chris jansing', 60), ('tamron hall', 57), ('ari melber', 57), ('joy-ann reid', 56), ('keith olbermann', 55), ('anthony bourdain', 55), ('john berman', 51), ('steve kornacki', 50), ('michael steele', 47), ('thomas roberts', 47), ('alex witt', 47), ('laura ingraham', 46), ('chris christie', 46), ('brooke baldwin', 46), ('martin bashir', 45), ('eugene robinson', 43), ('dylan ratigan', 43), ('david corn', 42), ('howard fineman', 41), ('jeffrey toobin', 40), ('willie geist', 40), ('michael smerconish', 40), ('christopher michael cillizza', 39), ('karen finney', 39), ('wolf blitzer', 38), ('brian williams', 38), ('ashleigh banfield', 37), ('craig melvin', 37), ('e. j. dionne', 37), ('shannon bream', 36)]
# =============
# ============= Climate =============
# [('chris matthews', 450), ('barack obama', 391), ('rachel maddow', 276), ('ed schultz', 180), ('donald trump', 167), ('mitt romney', 125), ('chris cuomo', 123), ("lawrence o'donnell", 118), ('chris hayes', 116), ('sean hannity', 110), ('chuck todd', 102), ('don lemon', 101), ('anderson cooper', 73), ('john berman', 70), ('willie geist', 64), ('al sharpton', 62), ('john boehner', 62), ('andrea mitchell', 59), ('joe scarborough', 59), ('tucker carlson', 55), ('laura ingraham', 53), ('joe biden', 53), ('mika brzezinski', 51), ('alex wagner', 50), ('david gregory', 49), ('michael smerconish', 49), ('newt gingrich', 47), ('tamron hall', 46), ('brooke baldwin', 45), ('chris christie', 45), ('kristen welker', 44), ('melissa harris-perry', 42), ('ari melber', 42), ('lynn smith', 40), ('alisyn camerota', 40), ('nancy pelosi', 40), ('shannon bream', 40), ('luke russert', 39), ('wolf blitzer', 39), ('dylan ratigan', 38), ('anthony bourdain', 37), ('rick santorum', 37), ('chris jansing', 37), ('robert mueller', 36), ('pete williams', 35), ('thomas roberts', 35), ('paul ryan', 33), ('greg gutfeld', 33), ('jeanine pirro', 32), ('mitch mcconnell', 32)]
# =============
